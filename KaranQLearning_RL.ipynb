# %%
import numpy as np
import gym
import random
import math

# %%
# Initialize the "Cart-Pole" environment
env = gym.make('CartPole-v1')

# No. of discrete states (bucket) per state dimension
NUM_BUCKETS = (1, 1, 6, 3)  # (x, x_dot, theta, theta_dot')
# No. of discrete actions
NUM_ACTIONS = env.action_space.n # (left, right)
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))
# set position between -2.4 to +2.4
STATE_BOUNDS[1] = [-2.4, 2.4]
# set angle between -15 to +15
STATE_BOUNDS[3] = [-math.radians(15), math.radians(15)]
# Index of the action

# Q table creation
Qtable = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,))

# constant for learning and exploration
MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1

# constants for simulation
TOTAL_EPISODES = 200
# Iterate 1 episode for MAX_T Time
MAX_T = 250
# No. of times for which pole will not fall
SOLVED_T = 200


def get_exploreRate(t):
    #Logrithmic decaying explore rate
    return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25.0)))    

def get_learningRate(t):
    #Logrithmic decaying learning rate
    return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25.0))) 


def choose_action(state, exploreRate):
    
    if random.random() < exploreRate:
        # Select a random action
        action = env.action_space.sample()
    else:
        # Select action having highest Q
        action = np.argmax(Qtable[state])
    return action

#convert state values into descrete value
def state_to_bucket(state):
    bucketList = []
    for i in range(len(state)):
        # if state value is less than lower range 
        if state[i] <= STATE_BOUNDS[i][0]:
            val = 0
        # if state value is more than high range     
        elif state[i] >= STATE_BOUNDS[i][1]:
            val = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            boundRange = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/boundRange
            scaling = (NUM_BUCKETS[i]-1)/boundRange
            val = int(round(scaling*state[i] - offset))
        bucketList.append(val)
    return tuple(bucketList)

# %%
def QAgent():

    # call to get leraning and explore rate
    learningRate = get_learningRate(0)
    exploreRate = get_exploreRate(0)
    discountfactor = 0.99
    #string to print successfull Episodes
    successfulEp =""
    # to check wheter it meet our requirement (SOLVED = True ,when episode completed after 200 successful time step)
    SOLVED = False 
    
    for episode in range(TOTAL_EPISODES):
        SOLVED = False
        INSIDE_DONE = False
        # Reset the environment
        observation = env.reset()

        # the initial state
        state0 = state_to_bucket(observation)

        for t in range(MAX_T):
            # simulate
            env.render()
            # Select an action
            action = choose_action(state0, exploreRate)
            # Execute the action
            observation, Reward, done, _ = env.step(action)
            # Observe the result
            state = state_to_bucket(observation)
            # update the Q Table
            bestQ = np.amax(Qtable[state])
            Qtable[state0 + (action,)] += learningRate*(Reward + discountfactor*(bestQ) - Qtable[state0 + (action,)])
            # Assigning current state for next state
            state0 = state
            
            if done:
               print("Episode %d finished after %f time steps" % (episode, t))
               INSIDE_DONE = True
               # when pole does not fall for more than 200 time step
               if (t >= SOLVED_T):
                   SOLVED = True
               break
               
        if SOLVED:
            successfulEp += "\nEpisode %d finished after %f time steps" % (episode, t)
        elif INSIDE_DONE == False:
            print("Episode %d finished after %f time steps" % (episode, t))
            successfulEp += "\nEpisode %d finished after %f time steps" % (episode, t)
            
        # Update learning and exploration rate
        exploreRate = get_exploreRate(episode)
        learningRate = get_learningRate(episode)

    
    print("\n------successful Episodes--------")            
    print(successfulEp)        


if __name__ == "__main__":
    QAgent()
# Out:
# Episode 0 finished after 11.000000 time steps
# Episode 1 finished after 8.000000 time steps
# Episode 2 finished after 33.000000 time steps
# Episode 3 finished after 11.000000 time steps
# Episode 4 finished after 40.000000 time steps
# Episode 5 finished after 27.000000 time steps
# Episode 6 finished after 31.000000 time steps
# Episode 7 finished after 27.000000 time steps
# Episode 8 finished after 12.000000 time steps
# Episode 9 finished after 16.000000 time steps
# Episode 10 finished after 11.000000 time steps
# Episode 11 finished after 7.000000 time steps
# Episode 12 finished after 46.000000 time steps
# Episode 13 finished after 16.000000 time steps
# Episode 14 finished after 60.000000 time steps
# Episode 15 finished after 20.000000 time steps
# Episode 16 finished after 21.000000 time steps
# Episode 17 finished after 14.000000 time steps
# Episode 18 finished after 9.000000 time steps
# Episode 19 finished after 31.000000 time steps
# Episode 20 finished after 35.000000 time steps
# Episode 21 finished after 10.000000 time steps
# Episode 22 finished after 12.000000 time steps
# Episode 23 finished after 21.000000 time steps
# Episode 24 finished after 11.000000 time steps
# Episode 25 finished after 9.000000 time steps
# Episode 26 finished after 34.000000 time steps
# Episode 27 finished after 10.000000 time steps
# Episode 28 finished after 16.000000 time steps
# Episode 29 finished after 12.000000 time steps
# Episode 30 finished after 16.000000 time steps
# Episode 31 finished after 27.000000 time steps
# Episode 32 finished after 25.000000 time steps
# Episode 33 finished after 16.000000 time steps
# Episode 34 finished after 14.000000 time steps
# Episode 35 finished after 19.000000 time steps
# Episode 36 finished after 10.000000 time steps
# Episode 37 finished after 10.000000 time steps
# Episode 38 finished after 13.000000 time steps
# Episode 39 finished after 17.000000 time steps
# Episode 40 finished after 10.000000 time steps
# Episode 41 finished after 76.000000 time steps
# Episode 42 finished after 29.000000 time steps
# Episode 43 finished after 11.000000 time steps
# Episode 44 finished after 17.000000 time steps
# Episode 45 finished after 132.000000 time steps
# Episode 46 finished after 18.000000 time steps
# Episode 47 finished after 23.000000 time steps
# Episode 48 finished after 30.000000 time steps
# Episode 49 finished after 34.000000 time steps
# Episode 50 finished after 16.000000 time steps
# Episode 51 finished after 13.000000 time steps
# Episode 52 finished after 15.000000 time steps
# Episode 53 finished after 18.000000 time steps
# Episode 54 finished after 18.000000 time steps
# Episode 55 finished after 9.000000 time steps
# Episode 56 finished after 33.000000 time steps
# Episode 57 finished after 22.000000 time steps
# Episode 58 finished after 22.000000 time steps
# Episode 59 finished after 8.000000 time steps
# Episode 60 finished after 18.000000 time steps
# Episode 61 finished after 12.000000 time steps
# Episode 62 finished after 46.000000 time steps
# Episode 63 finished after 17.000000 time steps
# Episode 64 finished after 20.000000 time steps
# Episode 65 finished after 11.000000 time steps
# Episode 66 finished after 18.000000 time steps
# Episode 67 finished after 23.000000 time steps
# Episode 68 finished after 30.000000 time steps
# Episode 69 finished after 36.000000 time steps
# Episode 70 finished after 26.000000 time steps
# Episode 71 finished after 12.000000 time steps
# Episode 72 finished after 13.000000 time steps
# Episode 73 finished after 182.000000 time steps
# Episode 74 finished after 20.000000 time steps
# Episode 75 finished after 11.000000 time steps
# Episode 76 finished after 24.000000 time steps
# Episode 77 finished after 29.000000 time steps
# Episode 78 finished after 34.000000 time steps
# Episode 79 finished after 23.000000 time steps
# Episode 80 finished after 35.000000 time steps
# Episode 81 finished after 33.000000 time steps
# Episode 82 finished after 9.000000 time steps
# Episode 83 finished after 36.000000 time steps
# Episode 84 finished after 36.000000 time steps
# Episode 85 finished after 20.000000 time steps
# Episode 86 finished after 19.000000 time steps
# Episode 87 finished after 20.000000 time steps
# Episode 88 finished after 18.000000 time steps
# Episode 89 finished after 207.000000 time steps
# Episode 90 finished after 28.000000 time steps
# Episode 91 finished after 11.000000 time steps
# Episode 92 finished after 11.000000 time steps
# Episode 93 finished after 63.000000 time steps
# Episode 94 finished after 19.000000 time steps
# Episode 95 finished after 13.000000 time steps
# Episode 96 finished after 50.000000 time steps
# Episode 97 finished after 18.000000 time steps
# Episode 98 finished after 67.000000 time steps
# Episode 99 finished after 11.000000 time steps
# Episode 100 finished after 51.000000 time steps
# Episode 101 finished after 17.000000 time steps
# Episode 102 finished after 13.000000 time steps
# Episode 103 finished after 9.000000 time steps
# Episode 104 finished after 9.000000 time steps
# Episode 105 finished after 12.000000 time steps
# Episode 106 finished after 14.000000 time steps
# Episode 107 finished after 65.000000 time steps
# Episode 108 finished after 83.000000 time steps
# Episode 109 finished after 11.000000 time steps
# Episode 110 finished after 66.000000 time steps
# Episode 111 finished after 53.000000 time steps
# Episode 112 finished after 93.000000 time steps
# Episode 113 finished after 16.000000 time steps
# Episode 114 finished after 58.000000 time steps
# Episode 115 finished after 11.000000 time steps
# Episode 116 finished after 41.000000 time steps
# Episode 117 finished after 128.000000 time steps
# Episode 118 finished after 11.000000 time steps
# Episode 119 finished after 49.000000 time steps
# Episode 120 finished after 13.000000 time steps
# Episode 121 finished after 100.000000 time steps
# Episode 122 finished after 8.000000 time steps
# Episode 123 finished after 134.000000 time steps
# Episode 124 finished after 114.000000 time steps
# Episode 125 finished after 74.000000 time steps
# Episode 126 finished after 32.000000 time steps
# Episode 127 finished after 79.000000 time steps
# Episode 128 finished after 23.000000 time steps
# Episode 129 finished after 57.000000 time steps
# Episode 130 finished after 27.000000 time steps
# Episode 131 finished after 75.000000 time steps
# Episode 132 finished after 11.000000 time steps
# Episode 133 finished after 9.000000 time steps
# Episode 134 finished after 27.000000 time steps
# Episode 135 finished after 16.000000 time steps
# Episode 136 finished after 9.000000 time steps
# Episode 137 finished after 47.000000 time steps
# Episode 138 finished after 13.000000 time steps
# Episode 139 finished after 38.000000 time steps
# Episode 140 finished after 249.000000 time steps
# Episode 141 finished after 220.000000 time steps
# Episode 142 finished after 247.000000 time steps
# Episode 143 finished after 249.000000 time steps
# Episode 144 finished after 188.000000 time steps
# Episode 145 finished after 12.000000 time steps
# Episode 146 finished after 133.000000 time steps
# Episode 147 finished after 11.000000 time steps
# Episode 148 finished after 239.000000 time steps
# Episode 149 finished after 249.000000 time steps
# Episode 150 finished after 204.000000 time steps
# Episode 151 finished after 249.000000 time steps
# Episode 152 finished after 249.000000 time steps
# Episode 153 finished after 249.000000 time steps
# Episode 154 finished after 249.000000 time steps
# Episode 155 finished after 249.000000 time steps
# Episode 156 finished after 249.000000 time steps
# Episode 157 finished after 209.000000 time steps
# Episode 158 finished after 249.000000 time steps
# Episode 159 finished after 181.000000 time steps
# Episode 160 finished after 249.000000 time steps
# Episode 161 finished after 249.000000 time steps
# Episode 162 finished after 249.000000 time steps
# Episode 163 finished after 249.000000 time steps
# Episode 164 finished after 249.000000 time steps
# Episode 165 finished after 249.000000 time steps
# Episode 166 finished after 249.000000 time steps
# Episode 167 finished after 249.000000 time steps
# Episode 168 finished after 249.000000 time steps
# Episode 169 finished after 249.000000 time steps
# Episode 170 finished after 249.000000 time steps
# Episode 171 finished after 249.000000 time steps
# Episode 172 finished after 249.000000 time steps
# Episode 173 finished after 249.000000 time steps
# Episode 174 finished after 249.000000 time steps
# Episode 175 finished after 249.000000 time steps
# Episode 176 finished after 249.000000 time steps
# Episode 177 finished after 249.000000 time steps
# Episode 178 finished after 249.000000 time steps
# Episode 179 finished after 249.000000 time steps
# Episode 180 finished after 249.000000 time steps
# Episode 181 finished after 249.000000 time steps
# Episode 182 finished after 249.000000 time steps
# Episode 183 finished after 249.000000 time steps
# Episode 184 finished after 249.000000 time steps
# Episode 185 finished after 249.000000 time steps
# Episode 186 finished after 249.000000 time steps
# Episode 187 finished after 249.000000 time steps
# Episode 188 finished after 249.000000 time steps
# Episode 189 finished after 249.000000 time steps
# Episode 190 finished after 249.000000 time steps
# Episode 191 finished after 249.000000 time steps
# Episode 192 finished after 249.000000 time steps
# Episode 193 finished after 249.000000 time steps
# Episode 194 finished after 249.000000 time steps
# Episode 195 finished after 249.000000 time steps
# Episode 196 finished after 249.000000 time steps
# Episode 197 finished after 249.000000 time steps
# Episode 198 finished after 249.000000 time steps
# Episode 199 finished after 249.000000 time steps
#
# ------successful Episodes--------
#
# Episode 89 finished after 207.000000 time steps
# Episode 140 finished after 249.000000 time steps
# Episode 141 finished after 220.000000 time steps
# Episode 142 finished after 247.000000 time steps
# Episode 143 finished after 249.000000 time steps
# Episode 148 finished after 239.000000 time steps
# Episode 149 finished after 249.000000 time steps
# Episode 150 finished after 204.000000 time steps
# Episode 151 finished after 249.000000 time steps
# Episode 152 finished after 249.000000 time steps
# Episode 153 finished after 249.000000 time steps
# Episode 154 finished after 249.000000 time steps
# Episode 155 finished after 249.000000 time steps
# Episode 156 finished after 249.000000 time steps
# Episode 157 finished after 209.000000 time steps
# Episode 158 finished after 249.000000 time steps
# Episode 160 finished after 249.000000 time steps
# Episode 161 finished after 249.000000 time steps
# Episode 162 finished after 249.000000 time steps
# Episode 163 finished after 249.000000 time steps
# Episode 164 finished after 249.000000 time steps
# Episode 165 finished after 249.000000 time steps
# Episode 166 finished after 249.000000 time steps
# Episode 167 finished after 249.000000 time steps
# Episode 168 finished after 249.000000 time steps
# Episode 169 finished after 249.000000 time steps
# Episode 170 finished after 249.000000 time steps
# Episode 171 finished after 249.000000 time steps
# Episode 172 finished after 249.000000 time steps
# Episode 173 finished after 249.000000 time steps
# Episode 174 finished after 249.000000 time steps
# Episode 175 finished after 249.000000 time steps
# Episode 176 finished after 249.000000 time steps
# Episode 177 finished after 249.000000 time steps
# Episode 178 finished after 249.000000 time steps
# Episode 179 finished after 249.000000 time steps
# Episode 180 finished after 249.000000 time steps
# Episode 181 finished after 249.000000 time steps
# Episode 182 finished after 249.000000 time steps
# Episode 183 finished after 249.000000 time steps
# Episode 184 finished after 249.000000 time steps
# Episode 185 finished after 249.000000 time steps
# Episode 186 finished after 249.000000 time steps
# Episode 187 finished after 249.000000 time steps
# Episode 188 finished after 249.000000 time steps
# Episode 189 finished after 249.000000 time steps
# Episode 190 finished after 249.000000 time steps
# Episode 191 finished after 249.000000 time steps
# Episode 192 finished after 249.000000 time steps
# Episode 193 finished after 249.000000 time steps
# Episode 194 finished after 249.000000 time steps
# Episode 195 finished after 249.000000 time steps
# Episode 196 finished after 249.000000 time steps
# Episode 197 finished after 249.000000 time steps
# Episode 198 finished after 249.000000 time steps
# Episode 199 finished after 249.000000 time steps
